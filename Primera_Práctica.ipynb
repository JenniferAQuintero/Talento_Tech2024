# %% [markdown]
# <a href="https://colab.research.google.com/github/JenniferAQuintero/Talento_Tech2024/blob/main/Primera_Pr%C3%A1ctica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Práctica 1 de Talento Tech: Incluye importar un Dataset

# %%
#Paso 1: Debo tener el archivo en una carpeta
#Paso 2: Debo establecer una conexión con la carpeta
#Paso 3: Debo ejecutar la celda de la conexión y revisar que este OK

# %% [markdown]
# #Suma de variables

# %%
#Python program to add two values
#variable e input
val1 = '10'
val2 = '12'

#Add two values
#proceso
suma = val1 + val2

#outpt -salida
print(suma)
# Out:
# 1012

# %% [markdown]
# # Ingreso de Nuevos Datos

# %%
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive') # Establecemos la conexión através del método mount
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Establezc la conexión con mi fuente y con el DatFrame de Prueba
#Cargar el Excel
path ='/content/drive/MyDrive/Colab Notebooks/DA_TalentoTech/data/Ventas.xlsx'
file = 'Ventas.xlsx'

# %%
#Importamos la libreria para manipulación de datos llamada Pandas
import pandas as pd

# %%
#Creamos un DatFrame de Pandas con los datos suministrados
df = pd.read_excel(path)

# %%
df.head()
# Out:
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %%
df.head(20)
# Out:
#      Region      Producto Vendedor  Ventas
# 0   Central    Accesorios    David    8287
# 1   Central    Accesorios    Karen    6909
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 6      Este    Accesorios      Ana    9323
# 7      Este    Accesorios    Lucas    7667
# 8      Este  Dispositivos      Ana   10348
# 9      Este  Dispositivos    Lucas    9312
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 14    Oeste  Dispositivos    Kevin   10711
# 15    Oeste  Dispositivos     Sara    8780
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151

# %%
df.head(10)
# Out:
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098
# 5  Central      Sistemas    Karen   30633
# 6     Este    Accesorios      Ana    9323
# 7     Este    Accesorios    Lucas    7667
# 8     Este  Dispositivos      Ana   10348
# 9     Este  Dispositivos    Lucas    9312

# %%
#variables input

# %% [markdown]
# # Creación y Lecturas de DataFrames:
#
#
# *   pd.DataFrame(data): Crea un DataFrame a partir de Datos
#
# *   pd.read_csv('archivo.csv'): Lee un archivo CSV y Crea un DataFrame
#
#
# *   pd.read_excel('archivo.xlsx'): Lee un archivo Excel y Crea un DataFrame
